# %% [markdown]
# <a href="https://colab.research.google.com/github/Simranpurswani/data-science-machine-learning-assignments/blob/main/Module-04-Regression/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Student": [
        "Rahul", "Priya", "Aman", "Neha", "Karan",
        "Sneha", "Rohit", "Anjali", "Vikas", "Pooja"
    ],

    "Actual": [
        1, 1, 0, 1, 0,
        1, 0, 0, 1, 0
    ],

    "Predicted": [
        1, 1, 1, 1, 0,
        0, 0, 1, 1, 0
    ]
}

df = pd.DataFrame(data)

df
# Out:
#   Student  Actual  Predicted
# 0   Rahul       1          1
# 1   Priya       1          1
# 2    Aman       0          1
# 3    Neha       1          1
# 4   Karan       0          0
# 5   Sneha       1          0
# 6   Rohit       0          0
# 7  Anjali       0          1
# 8   Vikas       1          1
# 9   Pooja       0          0

# %%
#Confusion Matrix
#True Positives --> TP --> The model correctly predicts the positive class
# TP = 1 ===> Rahul, Priya, Neha, Vikas

#True Negative --> TN --> The model correctly predicts the negative class
# TN = 1 ===> Karan, Rohit, Pooja

#False Positive --> FP --> the model incorrectly predicts it to be a positive class --> False Alarm
# FP = 1 ==> Aman, Anjali

#False Negative --> FN --> the model incorrectly predicts it to be a negative class
#FN = 1 ---> Sneha

# %%
tp = ((df["Actual"] == 1) & (df["Predicted"] == 1)).sum()
print("True positives:", tp)
# Out:
# True positives: 4

# %%
fp = ((df["Actual"] == 0) & (df["Predicted"] == 1)).sum()
print("False positives:", fp)
# Out:
# False positives: 2

# %%
tn = ((df["Actual"] == 0) & (df["Predicted"] == 0)).sum()
print("True Negatives:", tn)

# %%
fn = ((df["Actual"] == 1) & (df["Predicted"] == 0)).sum()
print("False Negatives:", fn)
# Out:
# False Negatives: 1

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(df["Actual"], df["Predicted"])

print(cm)
# Out:
# [[3 2]
#  [1 4]]

# %%
#                     Predicted
#                   0          1
#               -------------------
# Actual     0   | TN = 3   | FP = 2 |
#            1   | FN = 1   | TP = 4 |
#               -------------------
